# %%
 # Python Basics: Variables, Input/Output, Operators
# Q 1.	Write a program that takes the radius as input and calculates the area and circumference of a circle.
import math

radius = float(input("Enter the radius of the circle: "))

area = math.pi * radius ** 2
circumference = 2 * math.pi * radius

print(f"Area of the circle: {area:.2f}")
print(f"Circumference of the circle: {circumference:.2f}")
# Out:
# Enter the radius of the circle: 12
# Area of the circle: 452.39
# Circumference of the circle: 75.40

# %%
# 2. Write a program to check if a number is divisible by both 3 and 5.

number = int(input("Enter a number: "))

if number % 3 == 0 and number % 5 == 0:
    print(f"{number} is divisible by both 3 and 5.")
else:
    print(f"{number} is not divisible by both 3 and 5.")
# Out:
# Enter a number: 15
# 15 is divisible by both 3 and 5.

# %%
# 3. Write a program that takes a 4-digit number from the user and prints the sum of its digits.

number = input("Enter a 4-digit number: ")

if len(number) == 4 and number.isdigit():
    digit_sum = sum(int(digit) for digit in number)
    print(f"Sum of the digits: {digit_sum}")
else:
    print("Please enter a valid 4-digit number.")
# Out:
# Enter a 4-digit number: 1452
# Sum of the digits: 12
